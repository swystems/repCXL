# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Synchrony tests & read retries
#
# Test the effect of read retries and synchrony in MONSTER and ABE.
#
# p9999 is actually worst case p9999 across a set of clients which
# technically is p9999899, we refer to it as worst-case p9999.

# %%
read_retries = [0, 1, 10, 100, 1000]

# 9 processes (low contention)
print("9 processes, ycab a low contention")

p9_abe_tput = [ 263361, 480625, 517672, 537530, 548785]
p9_abe_rlat = [5.57, 2.70, 2.38, 1.60, 1.60 ] 
p9_abe_wlat = [1.28, 1.30, 1.31, 1.32, 1.33 ] 
p9_abe_rlat_p9999 = [2000, 5990, 2160, 127, 163]
p9_abe_wlat_p9999 = [5070, 5410, 5410, 5.35, 5.64]
p9_abe_avglat = (np.array(p9_abe_rlat) + np.array(p9_abe_wlat))/2
p9_abe_dr = [ 2907 / 1004104, 609 / 1003285, 304 / 1003285, 81 / 1005123, 11 / 1005283]

# 0% sync
p9_monster10r_tput = [ 249315, 302564, 303764, 303764, 303764]
p9_monster10r_rlat = [2.95, 1.47, 1.46, 1.58, 1.53]
p9_monster10r_wlat = [4.31, 4.35, 4.34, 4.38, 4.38] 
p9_monster10r_rlat_p9999 = [1840, 5.65, 5.64, 5.55, 5.55]
p9_monster10r_wlat_p9999 = [17.40, 18.93, 19.59, 18.47, 18.47]
p9_monster10r_avglat = (np.array(p9_monster10r_rlat) + np.array(p9_monster10r_wlat))/2
p9_monster10r_dr = [ 0.137, 7 / 1005092, 1 / 1005678,  1 / 1005678, 1 / 1005678]
# 
print(f'1200r sync rate: {1 - 791328/1005007} ')
p9_monster1200r_tput = [215009, 272127, 272980, 272669, 272669]
p9_monster1200r_rlat = [2.68, 1.59, 1.59, 1.59, 1.59]
p9_monster1200r_wlat = [5.44, 5.58, 5.58, 5.58, 5.58]
p9_monster1200r_rlat_p9999 = [1730, 5.23, 5.43, 5.43,5.43 ]
p9_monster1200r_wlat_p9999 = [25, 26.5, 24.8, 25.4, 25.4]
p9_monster1200r_avglat = (np.array(p9_monster1200r_rlat) + np.array(p9_monster1200r_wlat))/2
p9_monster1200r_dr = [1183 / 1005678, 6 / 1003285, 1 / 1004897, 1 / 1003285, 1 / 1003285]
#
print(f'1300r sync rate: {1 - 249138 / 1005193} ')
p9_monster1300r_tput = [197428, 273964, 273754, 273752, 273752 ]
p9_monster1300r_rlat = [3.30, 1.58, 1.58, 1.57, 1.59]
p9_monster1300r_wlat = [5.45, 5.58, 5.58, 5.58, 5.58]
p9_monster1300r_rlat_p9999 = [1830, 5.45,5.45,5.45,5.45 ]
p9_monster1300r_wlat_p9999 = [22.86, 25.8, 24.7, 25.85, 25.85]
p9_monster1300r_avglat = (np.array(p9_monster1300r_rlat) + np.array(p9_monster1300r_wlat))/2
p9_monster1300r_dr = [1749 / 1005521, 5 / 1005092, 1 / 1005007, 1 / 1005193, 1 / 1005193 ]
#
print(f'1700r sync rate: {1 - 10325 / 1005193} ')
p9_monster1700r_tput = [ 197909, 233959, 233451, 233743, 233743 ]
p9_monster1700r_rlat = [3.07, 1.58, 1.56, 1.58, 1.60]
p9_monster1700r_wlat = [8.83, 6.83, 6.85, 6.86, 6.86] 
p9_monster1700r_rlat_p9999 = [9620, 5.16, 5.34, 5.28, 5.28]
p9_monster1700r_wlat_p9999 = [27.8, 29.18, 28.71, 30.19, 30.19] 
p9_monster1700r_avglat = (np.array(p9_monster1700r_rlat) + np.array(p9_monster1700r_wlat))/2
p9_monster1700r_dr = [ 536 / 1005193, 4 / 1005193,  1 / 1005193, 1 / 1005193, 1 / 1005193 ]

# p9_loggeronly_tput = [28731, 28731, 28731, 28731, 28731]
p9_loggeronly_tput = [2300, 2300,2300,2300,2300]
p9_loggeronly_rlat = np.array([1.26,1.26,1.26,1.26,1.26])
# p9_loggeronly_wlat = np.array([67.69,67.69,67.69,67.69,67.69])
p9_loggeronly_wlat = np.array([1740,1740,1740,1740,1740])
p9_loggeronly_rlat_p9999 = np.array([32.95, 32.95, 32.95, 32.95, 32.95])
p9_loggeronly_wlat_p9999 = np.array([2180, 2180, 2180,2180,2180])

p9_loggeronly_avglat = (p9_loggeronly_wlat + p9_loggeronly_rlat) /2 

p9_lock_tput = [222723, 222723, 222723, 222723, 222723]
p9_lock_rlat = [4.73, 4.73, 4.73, 4.73, 4.73]
p9_lock_wlat = [3.27, 3.27, 3.27, 3.27, 3.27]
p9_lock_rlat_p9999 = [17.34, 17.34, 17.34, 17.34, 17.34]
p9_lock_wlat_p9999 = [9.52, 9.52, 9.52, 9.52, 9.52]
p9_lock_avglat = (np.array(p9_lock_rlat) + np.array(p9_lock_wlat))/2
swarm_ib_from_paper_tput = [264000, 264000, 264000, 264000, 264000]
swarm_ib_from_paper_lat = [2.7, 2.7, 2.7, 2.7, 2.7]

swarm_ib_cloudlab_tput = [123000,123000,123000,123000,123000]
swarm_ib_cloudlab_rlat = [5.2,5.2,5.2,5.2,5.2]
swarm_ib_cloudlab_wlat = [6.32,6.32,6.32,6.32,6.32]
swarm_ib_cloudlab_avglat = (np.array(swarm_ib_cloudlab_rlat)+np.array(swarm_ib_cloudlab_rlat))/2
swarm_ib_cloudlab_rlat_p999 = [11.10, 11.10,11.10,11.10,11.10]
swarm_ib_cloudlab_wlat_p999 = [13.220,13.220,13.220,13.220,13.220]
# 64 processes (medium contention)
print("64 processes  ycsb a (medium contention)")

p64_abe_tput = [ 176353, 196211, 260000, 253067, 250067]
p64_abe_rlat = [9.40, 8.15, 4.90, 4.63, 4.70]
p64_abe_wlat = [1.72, 1.82, 1.86, 2.15, 2.14]
p64_abe_rlat_p9999 = [11700, 11050, 2610, 1200, 610 ]
p64_abe_wlat_p9999 = [12.90, 19.75, 21, 27, 28]
p64_abe_avglat = (np.array(p64_abe_rlat) + np.array(p64_abe_wlat)) / 2
p64_abe_dr = [ 35973 / 1004710, 19278 / 1004710, 5068 / 1005399, 152 / 1004813, 1 / 1004813] 
# 0% sync
p64_monster10r_tput = [79290, 103688, 104174, 104422, 104422]
p64_monster10r_rlat = [10.53, 2.08, 1.75, 1.73, 1.73]
p64_monster10r_wlat = [15.12, 16.8, 16.94, 16.91, 16.91]
p64_monster10r_rlat_p9999 = [10690, 14.7, 11.2, 7.6, 7.6]
p64_monster10r_wlat_p9999 = [4070, 3700, 3780, 2590, 2590]
p64_monster10r_avglat = (np.array(p64_monster10r_rlat) + np.array(p64_monster10r_wlat))/2
p64_monster10r_dr = [ 5241 / 1004813, 120 / 1004506, 4 / 1005511, 4 / 1005511]
# 
# print(f'1300r sync rate: {1 - 898928 / 1005193} ')
# p64_monster1300r_tput = [ 115000, 18200, 18600, 189000, 189000 ]
# p64_monster1300r_dr = [8481 / 1004710, 129 / 1004637, 1 / 1004967, 1 / 1004967, 1 / 1004967, 1 / 1004967 ]
# 
print(f'1500r sync rate: {1 - 642958 / 1005193} ')
p64_monster1500r_tput = [ 111000, 180000, 185000, 185000, 185000 ]
p64_monster1500r_rlat = [9.40, 2.10, 1.63, 1.63, 1.63] 
p64_monster1500r_wlat = [8.65, 8.62, 8.61, 8.61, 8.61] 
p64_monster1500r_rlat_p9999 = [11000, 15, 13, 9.5, 9.5] 
p64_monster1500r_wlat_p9999 = [230, 210, 214, 200, 200] 
p64_monster1500r_avglat = (np.array(p64_monster1500r_rlat) + np.array(p64_monster1500r_wlat))/2
p64_monster1500r_dr = [8705 / 1006615, 104 / 1004710, 1 / 1005283, 1 / 1005283, 1 / 1005283 ]
# 
# print(f'1700r sync rate: {1 - 392891 / 1005193} ')
# p64_monster1700r_tput = [118000, 175000, 181000, 181000, 181000 ]
# p64_monster1700r_dr = [ 9625 / 1004967, 91 / 1004813, 1 / 1004813, 1 / 1004813, 1 / 1004813 ]
# 
print(f'2000r sync rate: {1 - 205225 / 1005193} ')
p64_monster2000r_tput = [118000, 173000, 174000, 174000, 174000 ]
p64_monster2000r_rlat = [ 7.37, 1.84, 1.84, 1.84, 1.84]   
p64_monster2000r_wlat = [ 9.10, 9.10, 9.10, 9.10, 9.10]
p64_monster2000r_rlat_p9999 = [11400, 8.87, 8.04, 8.04, 8.04 ]   
p64_monster2000r_wlat_p9999 = [143, 157, 145, 145, 145 ]
p64_monster2000r_avglat = (np.array(p64_monster2000r_rlat)+np.array(p64_monster2000r_wlat)) / 2
p64_monster2000r_dr = [ 5769 / 1004710, 2 / 1004637, 1 / 1004967, 1 / 1004967, 1 / 1004967 ]
# 
print(f'3100r sync rate: {1 - 9183 / 1005193} ')
p64_monster3100r_tput = [88000, 145000, 145000, 145000, 145000 ]
p64_monster3100r_rlat = [10.80, 1.83, 1.83, 1.83, 1.83]
p64_monster3100r_wlat = [11.15, 10.78, 10.72, 10.75, 10.72 ]
p64_monster3100r_rlat_p9999 = [11500, 7, 7, 7, 7]
p64_monster3100r_wlat_p9999 = [172, 161, 171, 171, 171]
p64_monster3100r_avglat = (np.array(p64_monster3100r_rlat) + np.array(p64_monster3100r_wlat))/2
p64_monster3100r_dr = [ 7648 / 1005551, 6 / 1004967, 1 / 1004967, 1 / 1004967, 1 / 1004967 ]

p64_lock_tput = [45432, 45432, 45432, 45432, 45432]
p64_lock_rlat = [36.43,36.43,36.43,36.43,36.43]
p64_lock_wlat = [9.71, 9.71, 9.71, 9.71, 9.71]
p64_lock_rlat_p9999 = [6430, 6430, 6430, 6430, 6430]
p64_lock_wlat_p9999 = [1200, 1200, 1200, 1200, 1200]
p64_lock_avglat = (np.array(p64_lock_rlat) + np.array(p64_lock_wlat))/2


print("9 processes, ycsb a single key (medium contention)")

p9sk_abe_tput = [ 111598, 84118, 18307, 19124, 7718 ]
p9sk_abe_rlat = [19.66, 24.73, 108.07, 111, 111]
p9sk_abe_wlat = [1.19, 1.23, 2.49, 2.81, 2.81]
p9sk_abe_rlat_p9999 = [2170, 2180, 2190, 2150, 2150]
p9sk_abe_wlat_p9999 = [4.72, 4.95, 8.65, 8.76, 8076]
p9sk_abe_avglat = (np.array(p9sk_abe_rlat) + np.array(p9sk_abe_wlat))/2
p9sk_abe_dr = [ 8738 / 1005610, 11111 / 1005627, 54228 / 1005520, 24381 / 1006520, 25564 / 1005520 ] 

# 0% sync
p9sk_monster10r_tput = [51556, 94906, 126000, 127835, 127835 ] 
p9sk_monster10r_rlat = [ 33.15, 9.31, 1.86, 1.84, 1.84]
p9sk_monster10r_wlat = [ 5.18, 11.69, 14.31, 14.44, 14.44]
p9sk_monster10r_rlat_p9999 = [2140, 2000, 11.13, 11.14, 11.14]
p9sk_monster10r_wlat_p9999 = [178, 400, 440, 441, 441]
p9sk_monster10r_avglat = (np.array(p9sk_monster10r_rlat) + np.array(p9sk_monster10r_wlat))/2
p9sk_monster10r_dr = [ 106407 / 1005670, 7182 / 1005244, 1 / 1005627, 1 / 1005627, 1 / 1005627 ]
# 
print(f'1200r sync rate: {1 - 755871 / 1005193} ')
p9sk_monster1200r_tput = [ 40000, 114271, 121000, 121000, 121000  ]
p9sk_monster1200r_rlat = [ 42.97, 4.34, 1.74, 1.74, 1.74] 
p9sk_monster1200r_wlat = [ 6.39, 13.02, 14.06, 14.06, 14.06]
p9sk_monster1200r_rlat_p9999 = [2140, 1800, 10, 9.31, 9.31 ] 
p9sk_monster1200r_wlat_p9999 = [ 93, 130, 130, 130, 130 ]
p9sk_monster1200r_avglat = (np.array(p9sk_monster1200r_rlat) + np.array(p9sk_monster1200r_wlat))/2
p9sk_monster1200r_dr = [21494 / 1004063, 2637 / 1005610, 1 / 1006520, 1 / 1006520, 1 / 1006520 ]
# 
print(f'1500r sync rate: {1 - 252401 / 1005193} ')
p9sk_monster1500r_tput = [ 36000, 134000, 131000,  131000, 131000 ]
p9sk_monster1500r_rlat = [ 47.80, 3.75, 1.80, 1.79, 1.81]
p9sk_monster1500r_wlat = [ 6.75, 11.10, 13.26, 12.79, 12.80]
p9sk_monster1500r_rlat_p9999 = [2150, 1790, 9.48, 9.48, 9.48]
p9sk_monster1500r_wlat_p9999 = [70, 96, 106, 106, 106]
p9sk_monster1500r_avglat = (np.array(p9sk_monster1500r_rlat) + np.array(p9sk_monster1500r_wlat))/2
p9sk_monster1500r_dr = [ 23840 / 1004063, 1992 / 1004063, 2 / 1004063, 1 / 1004063, 1 / 1004063]
# 
print(f'2500r sync rate: {1 - 6951 / 1005193} ')
p9sk_monster2500r_tput = [ 36000, 111637, 113875, 112422, 112422 ]
p9sk_monster2500r_rlat = [45.59, 1.91, 1.69, 1.68, 1.68]
p9sk_monster2500r_wlat = [10.40, 15.66, 15.69, 15.79, 15.79]
p9sk_monster2500r_rlat_p9999 = [2130, 2100, 9.25, 9.38, 9.38]
p9sk_monster2500r_wlat_p9999 = [110, 130, 133, 140, 140 ]
p9sk_monster2500r_avglat = (np.array(p9sk_monster2500r_rlat) + np.array(p9sk_monster2500r_wlat))/2
p9sk_monster2500r_dr = [ 24862 / 1005610, 216 / 1005610, 2 / 1005670, 2 / 1005670, 2 / 1005670]

p9sk_lock_tput = [39251,39251,39251,39251,39251] 
p9sk_lock_rlat = [53.04,53.04,53.04,53.04,53.04] 
p9sk_lock_wlat = [9.95,9.95,9.95,9.95,9.95] 
p9sk_lock_rlat_p9999 = [727, 727, 727, 727, 727] 
p9sk_lock_wlat_p9999 = [130, 130, 130, 130, 130] 
p9sk_lock_avglat = (np.array(p9sk_lock_rlat)+np.array(p9sk_lock_wlat))/2  

p9sk_swarm_ib_cloudlab_tput = [81000,81000,81000,81000,81000]
p9sk_swarm_ib_cloudlab_rlat = [14.35,14.35,14.35,14.35,14.35]
p9sk_swarm_ib_cloudlab_wlat = [6.21,6.21,6.21,6.21,6.21]
p9sk_swarm_ib_cloudlab_avglat = (np.array(p9sk_swarm_ib_cloudlab_rlat)+np.array(p9sk_swarm_ib_cloudlab_rlat))/2
p9sk_swarm_ib_cloudlab_rlat_p999 = [51.1,51.1,51.1,51.1,51.1,]
p9sk_swarm_ib_cloudlab_wlat_p999 = [22.800,22.800,22.800,22.800,22.800]
# Out:
# 9 processes, ycab a low contention
# 1200r sync rate: 0.21261443950141645
# 1300r sync rate: 0.7521490897767891
# 1700r sync rate: 0.9897283407266068
# 64 processes  ycsb a (medium contention)
# 1500r sync rate: 0.36036363166078555
# 2000r sync rate: 0.7958352276627474
# 3100r sync rate: 0.9908644409581046
# 9 processes, ycsb a single key (medium contention)
# 1200r sync rate: 0.24803395964755026
# 1500r sync rate: 0.7489029469962485
# 2500r sync rate: 0.9930849100620478

# %%
plt.rcParams["font.family"] = "Linux Libertine"
# plt.rcParams["font.serif"] = "Linux Libertine"
plt.rcParams["font.size"] = 11
plt.rcParams['text.usetex'] = False
plt.rcParams["font.weight"] = "normal"

# %%
import numpy as np
# colors
swarm_color = "black"
lock_color = "magenta"
loggeronly_color = "saddlebrown"
# ── contention scenarios ───────────────────────────────────────────────────────
scenarios = [
    {
        "title": "low contention",
        "series": [
            {"label": "abe",               "rlat_p9999": p9_abe_rlat_p9999,       "wlat_p9999": p9_abe_wlat_p9999,       "tput": p9_abe_tput,       "avglat": p9_abe_avglat,       "rlat": p9_abe_rlat,       "wlat": p9_abe_wlat},
            {"label": "monster 0% sync",   "rlat_p9999": p9_monster10r_rlat_p9999, "wlat_p9999": p9_monster10r_wlat_p9999, "tput": p9_monster10r_tput, "avglat": p9_monster10r_avglat, "rlat": p9_monster10r_rlat, "wlat": p9_monster10r_wlat},
            {"label": "monster 21% sync",  "rlat_p9999": p9_monster1200r_rlat_p9999,"wlat_p9999": p9_monster1200r_wlat_p9999,"tput": p9_monster1200r_tput,"avglat": p9_monster1200r_avglat,"rlat": p9_monster1200r_rlat,"wlat": p9_monster1200r_wlat},
            {"label": "monster 75% sync",  "rlat_p9999": p9_monster1300r_rlat_p9999,"wlat_p9999": p9_monster1300r_wlat_p9999,"tput": p9_monster1300r_tput,"avglat": p9_monster1300r_avglat,"rlat": p9_monster1300r_rlat,"wlat": p9_monster1300r_wlat},
            {"label": "monster 98% sync",  "rlat_p9999": p9_monster1700r_rlat_p9999,"wlat_p9999": p9_monster1700r_wlat_p9999,"tput": p9_monster1700r_tput,"avglat": p9_monster1700r_avglat,"rlat": p9_monster1700r_rlat,"wlat": p9_monster1700r_wlat},
            {"label": "log-only (Raft)",  "rlat_p9999": p9_loggeronly_rlat_p9999 ,"wlat_p9999": p9_loggeronly_wlat_p9999 ,"tput": p9_loggeronly_tput,"avglat": p9_loggeronly_avglat,"rlat": p9_loggeronly_rlat,"wlat": p9_loggeronly_wlat, "style": ":.", "color": loggeronly_color },
            {"label": "CXL3-lock (Tigon)",      "rlat_p9999": p9_lock_rlat_p9999,       "wlat_p9999": p9_lock_wlat_p9999,       "tput": p9_lock_tput,       "avglat": p9_lock_avglat,       "rlat": p9_lock_rlat,       "wlat": p9_lock_wlat,       "style": "--2", "color": lock_color},
            {"label": "SWARM",             "rlat_p9999": None,                      "wlat_p9999": None,                      "tput": swarm_ib_cloudlab_tput,"avglat": swarm_ib_cloudlab_avglat,"rlat": swarm_ib_cloudlab_rlat,"wlat": swarm_ib_cloudlab_wlat, "style": ":*",  "color": swarm_color},
        ],
    },
    {
        "title": "medium contention",
        "series": [
            {"label": "abe",               "rlat_p9999": p64_abe_rlat_p9999,         "wlat_p9999": p64_abe_wlat_p9999,        "tput": p64_abe_tput,        "avglat": p64_abe_avglat,        "rlat": p64_abe_rlat,        "wlat": p64_abe_wlat},
            {"label": "monster 0% sync",   "rlat_p9999": p64_monster10r_rlat_p9999,  "wlat_p9999": p64_monster10r_wlat_p9999,  "tput": p64_monster10r_tput,  "avglat": p64_monster10r_avglat,  "rlat": p64_monster10r_rlat,  "wlat": p64_monster10r_wlat},
            {"label": "monster 31% sync",  "rlat_p9999": p64_monster1500r_rlat_p9999,"wlat_p9999": p64_monster1500r_wlat_p9999,"tput": p64_monster1500r_tput,"avglat": p64_monster1500r_avglat,"rlat": p64_monster1500r_rlat,"wlat": p64_monster1500r_wlat},
            {"label": "monster 79% sync",  "rlat_p9999": p64_monster2000r_rlat_p9999,"wlat_p9999": p64_monster2000r_wlat_p9999,"tput": p64_monster2000r_tput,"avglat": p64_monster2000r_avglat,"rlat": p64_monster2000r_rlat,"wlat": p64_monster2000r_wlat},
            {"label": "monster 99% sync",  "rlat_p9999": p64_monster3100r_rlat_p9999,"wlat_p9999": p64_monster3100r_wlat_p9999,"tput": p64_monster3100r_tput,"avglat": p64_monster3100r_avglat,"rlat": p64_monster3100r_rlat,"wlat": p64_monster3100r_wlat},
            {"label": "log-only (Raft)",  "rlat_p9999": p9_loggeronly_rlat_p9999 ,"wlat_p9999": p9_loggeronly_wlat_p9999 ,"tput": p9_loggeronly_tput,"avglat": p9_loggeronly_avglat,"rlat": p9_loggeronly_rlat,"wlat": p9_loggeronly_wlat, "style": ":.", "color": loggeronly_color},
            {"label": "CXL3-lock (Tigon)",      "rlat_p9999": p64_lock_rlat_p9999,        "wlat_p9999": p64_lock_wlat_p9999,        "tput": p64_lock_tput,        "avglat": p64_lock_avglat,        "rlat": p64_lock_rlat,        "wlat": p64_lock_wlat,        "style": "--2", "color": lock_color},
            {"label": "SWARM",              "rlat_p9999": None,                         "wlat_p9999": None,                         "tput": None,                  "avglat": None,                    "rlat": None,                  "wlat": None,                  "style": ":*",  "color": swarm_color},
        ],
    },
    {
        "title": "high contention",
        "series": [
            {"label": "abe",                "rlat_p9999": p9sk_abe_rlat_p9999,        "wlat_p9999": p9sk_abe_wlat_p9999,        "tput": p9sk_abe_tput,        "avglat": p9sk_abe_avglat,        "rlat": p9sk_abe_rlat,        "wlat": p9sk_abe_wlat},
            {"label": "monster 0% sync",    "rlat_p9999": p9sk_monster10r_rlat_p9999,  "wlat_p9999": p9sk_monster10r_wlat_p9999,  "tput": p9sk_monster10r_tput,  "avglat": p9sk_monster10r_avglat,  "rlat": p9sk_monster10r_rlat,  "wlat": p9sk_monster10r_wlat},
            {"label": "monster ~25% sync",  "rlat_p9999": p9sk_monster1200r_rlat_p9999,"wlat_p9999": p9sk_monster1200r_wlat_p9999,"tput": p9sk_monster1200r_tput,"avglat": p9sk_monster1200r_avglat,"rlat": p9sk_monster1200r_rlat,"wlat": p9sk_monster1200r_wlat},
            {"label": "monster ~75% sync",  "rlat_p9999": p9sk_monster1500r_rlat_p9999,"wlat_p9999": p9sk_monster1500r_wlat_p9999,"tput": p9sk_monster1500r_tput,"avglat": p9sk_monster1500r_avglat,"rlat": p9sk_monster1500r_rlat,"wlat": p9sk_monster1500r_wlat},
            {"label": "monster ~99% sync",  "rlat_p9999": p9sk_monster2500r_rlat_p9999,"wlat_p9999": p9sk_monster2500r_wlat_p9999,"tput": p9sk_monster2500r_tput,"avglat": p9sk_monster2500r_avglat,"rlat": p9sk_monster2500r_rlat,"wlat": p9sk_monster2500r_wlat},
            {"label": "log-only (Raft)",  "rlat_p9999": p9_loggeronly_rlat_p9999 ,"wlat_p9999": p9_loggeronly_wlat_p9999 ,"tput": p9_loggeronly_tput,"avglat": p9_loggeronly_avglat,"rlat": p9_loggeronly_rlat,"wlat": p9_loggeronly_wlat, "style": ":.", "color": loggeronly_color},
            {"label": "CXL3-lock (Tigon)",  "rlat_p9999": p9sk_lock_rlat_p9999,        "wlat_p9999": p9sk_lock_wlat_p9999,        "tput": p9sk_lock_tput,        "avglat": p9sk_lock_avglat,        "rlat": p9sk_lock_rlat,        "wlat": p9sk_lock_wlat,        "style": "--2", "color": lock_color},
            {"label": "SWARM",              "rlat_p9999": None,                         "wlat_p9999": None,                         "tput": None,                  "avglat": None,                    "rlat": None,                  "wlat": None,                  "style": ":*",  "color": swarm_color},
        ],
    },
]

# ── x-axis ─────────────────────────────────────────────────────────────────────
read_retries_even_space = [0, 1, 2, 3, 4]
read_retries_real       = [0, 1, 10, 100, 1000]
read_retries            = read_retries_even_space

# ── row definitions ────────────────────────────────────────────────────────────
# Each row: (y_label, data_key, log_scale)
# data_key=None triggers the derived max(rlat_p9999, wlat_p9999) row
rows = [
    ("Throughput (ops/sec)",   "tput",       False),
    ("Average latency (us)",   "avglat",     True),
    ("Read latency (us)",      "rlat",       True),
    ("Write latency (us)",     "wlat",       True),
    ("Read latency P9999",     "rlat_p9999", True),
    ("Write latency P9999",    "wlat_p9999", True),
    ("P9999 latency", None,         True),
]

# ── figure ─────────────────────────────────────────────────────────────────────
fig, axs = plt.subplots(len(rows), len(scenarios), sharey="row",
                        figsize=(9, 2 * len(rows)))

for ax1 in axs:
    for ax in ax1:
        ax.grid()

# ── tput y-ticks (row 0 only) ──────────────────────────────────────────────────
for ax in axs[0]:
    ax.set_yticks(
        [0, 100_000, 200_000, 300_000, 400_000, 500_000, 600_000],
        labels=["0", "100k", "200k", "300k", "400k", "500k", "600k"],
    )

# ── populate ───────────────────────────────────────────────────────────────────
for col, scenario in enumerate(scenarios):
    axs[0][col].set_title(scenario["title"])

    for row, (ylabel, key, log_scale) in enumerate(rows):
        ax = axs[row][col]

        if log_scale:
            ax.set_yscale("log")
        if row == len(rows) - 1:          # bottom row gets x-label
            ax.set_xlabel("read retries")
        if col == 0:                       # left column gets y-label
            ax.set_ylabel(ylabel)

        ax.set_xticks(read_retries_even_space, labels=read_retries_real)

        for s in scenario["series"]:
            style = s.get("style", "-")
            color = s.get("color", None)
            kwargs = dict(label=s["label"])
            if color:
                kwargs["color"] = color

            # derive y-values
            if key is None:               # max(read, write) P9999
                r, w = s["rlat_p9999"], s["wlat_p9999"]
                if r is None or w is None:
                    continue
                y = [max(rv, wv) for rv, wv in zip(r, w)]
            else:
                y = s[key]
                if y is None:
                    continue

            ax.plot(read_retries, y, style, **kwargs)

# ── legend (anchored to top-right subplot) ─────────────────────────────────────
axs[0][0].legend(loc="center", bbox_to_anchor=(1.6, 1.4), ncols=4)

# fig.tight_layout()

# %%
### paper plot

import numpy as np

# ── colors ─────────────────────────────────────────────────────────────────────
swarm_color      = "black"
lock_color       = "magenta"
loggeronly_color = "saddlebrown"

# ── series labels ──────────────────────────────────────────────────────────────
LABEL_LOBSTER    = "LOBSTER"
LABEL_MONSTER_A  = "MONSTER-0"
LABEL_MONSTER_R  = "MONSTER-50"
LABEL_LOGGERONLY = "Log-only (Raft)"

# ── series styles ──────────────────────────────────────────────────────────────
STYLE_LOBSTER    = "--*"
STYLE_MONSTER_A  = "-x"
STYLE_MONSTER_R  = "-."
STYLE_LOGGERONLY = ":3"

# ── series colors ──────────────────────────────────────────────────────────────
COLOR_LOBSTER    = None
COLOR_MONSTER_A  = None
COLOR_MONSTER_R  = None
COLOR_LOGGERONLY = loggeronly_color

# ── contention scenarios ───────────────────────────────────────────────────────
scenarios = [
    {
        "title": "Low contention",
        "series": [
            {"label": LABEL_LOBSTER,    "style": STYLE_LOBSTER,    "color": COLOR_LOBSTER,    "rlat_p9999": p9_abe_rlat_p9999,         "wlat_p9999": p9_abe_wlat_p9999,         "tput": p9_abe_tput,        "avglat": p9_abe_avglat,        "rlat": p9_abe_rlat,        "wlat": p9_abe_wlat},
            {"label": LABEL_MONSTER_A,  "style": STYLE_MONSTER_A,  "color": COLOR_MONSTER_A,  "rlat_p9999": p9_monster10r_rlat_p9999,  "wlat_p9999": p9_monster10r_wlat_p9999,  "tput": p9_monster10r_tput, "avglat": p9_monster10r_avglat, "rlat": p9_monster10r_rlat, "wlat": p9_monster10r_wlat},
            {"label": LABEL_MONSTER_R,  "style": STYLE_MONSTER_R,  "color": COLOR_MONSTER_R,  "rlat_p9999": p9_monster1300r_rlat_p9999,"wlat_p9999": p9_monster1300r_wlat_p9999, "tput": p9_monster1300r_tput,"avglat": p9_monster1300r_avglat,"rlat": p9_monster1300r_rlat,"wlat": p9_monster1300r_wlat},
            {"label": LABEL_LOGGERONLY, "style": STYLE_LOGGERONLY, "color": COLOR_LOGGERONLY, "rlat_p9999": p9_loggeronly_rlat_p9999,  "wlat_p9999": p9_loggeronly_wlat_p9999,  "tput": p9_loggeronly_tput, "avglat": p9_loggeronly_avglat, "rlat": p9_loggeronly_rlat, "wlat": p9_loggeronly_wlat},
        ],
    },
    {
        "title": "Med. contention",
        "series": [
            {"label": LABEL_LOBSTER,    "style": STYLE_LOBSTER,    "color": COLOR_LOBSTER,    "rlat_p9999": p64_abe_rlat_p9999,         "wlat_p9999": p64_abe_wlat_p9999,         "tput": p64_abe_tput,        "avglat": p64_abe_avglat,        "rlat": p64_abe_rlat,        "wlat": p64_abe_wlat},
            {"label": LABEL_MONSTER_A,  "style": STYLE_MONSTER_A,  "color": COLOR_MONSTER_A,  "rlat_p9999": p64_monster10r_rlat_p9999,  "wlat_p9999": p64_monster10r_wlat_p9999,  "tput": p64_monster10r_tput,  "avglat": p64_monster10r_avglat,  "rlat": p64_monster10r_rlat,  "wlat": p64_monster10r_wlat},
            {"label": LABEL_MONSTER_R,  "style": STYLE_MONSTER_R,  "color": COLOR_MONSTER_R,  "rlat_p9999": p64_monster1500r_rlat_p9999,"wlat_p9999": p64_monster1500r_wlat_p9999, "tput": p64_monster1500r_tput,"avglat": p64_monster1500r_avglat,"rlat": p64_monster1500r_rlat,"wlat": p64_monster1500r_wlat},
            {"label": LABEL_LOGGERONLY, "style": STYLE_LOGGERONLY, "color": COLOR_LOGGERONLY, "rlat_p9999": p9_loggeronly_rlat_p9999,   "wlat_p9999": p9_loggeronly_wlat_p9999,   "tput": p9_loggeronly_tput,  "avglat": p9_loggeronly_avglat,  "rlat": p9_loggeronly_rlat,  "wlat": p9_loggeronly_wlat},
        ],
    },
    {
        "title": "High contention",
        "series": [
            {"label": LABEL_LOBSTER,    "style": STYLE_LOBSTER,    "color": COLOR_LOBSTER,    "rlat_p9999": p9sk_abe_rlat_p9999,         "wlat_p9999": p9sk_abe_wlat_p9999,         "tput": p9sk_abe_tput,        "avglat": p9sk_abe_avglat,        "rlat": p9sk_abe_rlat,        "wlat": p9sk_abe_wlat},
            {"label": LABEL_MONSTER_A,  "style": STYLE_MONSTER_A,  "color": COLOR_MONSTER_A,  "rlat_p9999": p9sk_monster10r_rlat_p9999,  "wlat_p9999": p9sk_monster10r_wlat_p9999,  "tput": p9sk_monster10r_tput,  "avglat": p9sk_monster10r_avglat,  "rlat": p9sk_monster10r_rlat,  "wlat": p9sk_monster10r_wlat},
            {"label": LABEL_MONSTER_R,  "style": STYLE_MONSTER_R,  "color": COLOR_MONSTER_R,  "rlat_p9999": p9sk_monster1500r_rlat_p9999,"wlat_p9999": p9sk_monster1500r_wlat_p9999, "tput": p9sk_monster1500r_tput,"avglat": p9sk_monster1500r_avglat,"rlat": p9sk_monster1500r_rlat,"wlat": p9sk_monster1500r_wlat},
            {"label": LABEL_LOGGERONLY, "style": STYLE_LOGGERONLY, "color": COLOR_LOGGERONLY, "rlat_p9999": p9_loggeronly_rlat_p9999,    "wlat_p9999": p9_loggeronly_wlat_p9999,    "tput": p9_loggeronly_tput,   "avglat": p9_loggeronly_avglat,   "rlat": p9_loggeronly_rlat,   "wlat": p9_loggeronly_wlat},
        ],
    },
]

# ── x-axis ─────────────────────────────────────────────────────────────────────
read_retries_even_space = [0, 1, 2, 3, 4]
read_retries_real       = [0, 1, 10, 100, 1000]
read_retries            = read_retries_even_space

# ── row definitions ────────────────────────────────────────────────────────────
rows = [
    ("Tput (ops/s)",     "tput",   False),
    ("Avg lat. (us)",   "avglat", True),
    ("P9999", None,     True),
]

# ── figure ─────────────────────────────────────────────────────────────────────
fig, axs = plt.subplots(len(rows), len(scenarios), sharey="row", sharex="col",
                        figsize=(4.5, 1 * len(rows)), gridspec_kw={"wspace":0.1, "hspace":0.1})

for ax1 in axs:
    for ax in ax1:
        ax.grid()



# ── populate ───────────────────────────────────────────────────────────────────
for col, scenario in enumerate(scenarios):
    axs[0][col].set_title(scenario["title"], fontsize=11)

    for row, (ylabel, key, log_scale) in enumerate(rows):
        ax = axs[row][col]

        if log_scale:
            ax.set_yscale("log")
        if row == len(rows) - 1:
            ax.set_xlabel("Read retries")
        if col == 0:
            ax.set_ylabel(ylabel)

        ax.set_xticks(read_retries_even_space, labels=read_retries_real)

        for s in scenario["series"]:
            style  = s.get("style", "-")
            color  = s.get("color", None)
            kwargs = dict(label=s["label"])
            if color:
                kwargs["color"] = color

            if key is None:
                r, w = s["rlat_p9999"], s["wlat_p9999"]
                if r is None or w is None:
                    continue
                y = [max(rv, wv) for rv, wv in zip(r, w)]
            else:
                y = s[key]
                if y is None:
                    continue

            ax.plot(read_retries, y, style, **kwargs)

# ── tput y-ticks (row 0 only) ──────────────────────────────────────────────────
for ax in axs[0]:
    ax.set_yticks(
        [100_000, 300_000, 500_000],
        labels=["100k", "300k", "500k"],
    )


# for ax in axs[1]:
#     ax.set_yticks(
#         [10, 100, 1000],
#         labels=["$10^1$us", "100us", "1ms"],
#     )
    
# for ax in axs[2]:
#     ax.set_yticks(
#         [10, 100, 1000],
#         labels=["10", "100", "1000"],
#     )
    
# ── legend ─────────────────────────────────────────────────────────────────────
axs[0][0].legend(loc="center", bbox_to_anchor=(1.5, 1.8), ncols=2)

# %%
fig.savefig("rr_compare.pdf",bbox_inches = "tight", dpi=150)

# %% [markdown]
# ## YCSB B
# Latency throughput graph with 10 read retries for every approach

# %%
read_retries_even_space = [0,1,2,3]
read_retries_real = [0,1,10,100]
read_retries = read_retries_even_space

################# low contention
ycsbb_p9_abe_tput= [436055, 600125, 601161, 601161]
ycsbb_p9_abe_rlat = [2.26, 1.60, 1.60, 1.60] 
ycsbb_p9_abe_wlat = [1.25, 1.25, 1.25, 1.26]
ycsbb_p9_abe_rlat_p9999 = [6.8,6.8,6.8,6.8] 
ycsbb_p9_abe_wlat_p9999 = [5.03,5.03,5.03,5.03] 
ycsbb_p9_abe_avglat = (np.array(ycsbb_p9_abe_rlat) + np.array(ycsbb_p9_abe_wlat))/2


ycsbb_p9_monsterasync_tput= [516824, 572715, 572715, 572715]
ycsbb_p9_monsterasync_rlat = [1.73, 1.54, 1.54, 1.54] 
ycsbb_p9_monsterasync_wlat = [4.28, 4.31, 4.31, 4.31]
ycsbb_p9_monsterasync_rlat_p9999 = [5.45,5.45,5.45,5.45] 
ycsbb_p9_monsterasync_wlat_p9999 = [12.66,12.66,12.66,12.66]
ycsbb_p9_monsterasync_avglat = (np.array(ycsbb_p9_monsterasync_wlat) + np.array(ycsbb_p9_monsterasync_rlat))/2


ycsbb_p9_monstersync_tput= [451098, 534201, 534201, 534201]
ycsbb_p9_monstersync_rlat = [1.78, 1.54, 1.54, 1.54] 
ycsbb_p9_monstersync_wlat = [6.71, 6.69, 6.69, 6.69]
ycsbb_p9_monstersync_rlat_p9999 = [5.36,5.36,5.36,5.36] 
ycsbb_p9_monstersync_wlat_p9999 = [19.75,19.75,19.75,19.75]
ycsbb_p9_monstersync_avglat = (np.array(ycsbb_p9_monstersync_rlat) + np.array(ycsbb_p9_monstersync_wlat))/2


ycsbb_p9_lock_tput = [210326,210326,210326,210326]
ycsbb_p9_lock_rlat = [4.58,4.58,4.58,4.58]
ycsbb_p9_lock_wlat = [3.27,3.27,3.27,3.27]
ycsbb_p9_lock_rlat_p9999 = [16.39,16.39,16.39,16.39,16.39]
ycsbb_p9_lock_wlat_p9999 = [8.14,8.14,8.14,8.14,8.14]
ycsbb_p9_lock_avglat = (np.array(ycsbb_p9_lock_rlat)+np.array(ycsbb_p9_lock_rlat))/2


ycsbb_swarm_cloudlab_tput = [184000,184000,184000,184000]
ycsbb_swarm_cloudlab_rlat = np.array([4.8,4.8,4.8,4.8,4.8])
ycsbb_swarm_cloudlab_wlat = np.array([6.14,6.14,6.14,6.14,6.14])
ycsbb_swarm_cloudlab_avglat = (ycsbb_swarm_cloudlab_rlat+ycsbb_swarm_cloudlab_wlat)/2
ycsbb_swarm_cloudlab_rlat_p999 = [16.42,16.42,16.42,16.42,16.42,]
ycsbb_swarm_cloudlab_wlat_p999 = [18.64,18.64,18.64,18.64,18.64]

################# high contention

# NOTE: all latency reported below are for 10 read_retries bc current plot
# does not require others and can't be bothered changing the structure

ycsbb_p9sk_abe_tput= [37410,37410,37410,37410]
ycsbb_p9sk_abe_rlat = [29.87,29.87,29.87,29.87]
ycsbb_p9sk_abe_wlat = [2.03,2.03,2.03,2.03]
ycsbb_p9sk_abe_rlat_p9999 = [2210,2210,2210,2210]
ycsbb_p9sk_abe_wlat_p9999 = [7.43,7.43,7.43,7.43]
ycsbb_p9sk_abe_avglat = (np.array(ycsbb_p9sk_abe_rlat) + np.array(ycsbb_p9sk_abe_wlat))/2

ycsbb_p9sk_monsterasync_tput= [240282,240282,240282,240282]
ycsbb_p9sk_monsterasync_rlat = [3.74,3.74,3.74,3.74]
ycsbb_p9sk_monsterasync_wlat = [8.59,8.59,8.59,8.59]
ycsbb_p9sk_monsterasync_rlat_p9999 = [2180,2180,2180,2180]
ycsbb_p9sk_monsterasync_wlat_p9999 = [93.41,93.41,93.41,93.41]
ycsbb_p9sk_monsterasync_avglat = (np.array(ycsbb_p9sk_monsterasync_wlat) + np.array(ycsbb_p9sk_monsterasync_rlat))/2

ycsbb_p9sk_monstersync_tput= [312495,312495,312495,312495]
ycsbb_p9sk_monstersync_rlat = [2.57,2.57,2.57,2.57]
ycsbb_p9sk_monstersync_wlat = [11.26,11.26,11.26,11.26]
ycsbb_p9sk_monstersync_rlat_p9999 = [10.96,10.96,10.96,10.96]
ycsbb_p9sk_monstersync_wlat_p9999 = [121.81,121.81,121.81,121.81]
ycsbb_p9sk_monstersync_avglat = (np.array(ycsbb_p9sk_monstersync_rlat) + np.array(ycsbb_p9sk_monstersync_wlat))/2

ycsbb_p9sk_lock_tput = [38803, 38803,38803,38803]
ycsbb_p9sk_lock_rlat = [27.28,27.28,27.28,27.28  ]
ycsbb_p9sk_lock_wlat = [6.98, 6.98, 6.98, 6.98]
ycsbb_p9sk_lock_rlat_p9999 = [316.07,316.07,316.07,316.07]
ycsbb_p9sk_lock_wlat_p9999 = [43.32,43.32,43.32,43.32]
ycsbb_p9sk_lock_avglat = (np.array(ycsbb_p9sk_lock_rlat)+np.array(ycsbb_p9sk_lock_rlat))/2

# %%
fig, axs = plt.subplots(1,2,figsize=(4, 1.5), sharey="all")

mnodes = [3,7,14,21]

ax = axs[0]
abe_tput= [517672, 444434, 352620, 306652]
monsterasync_tput = [325026, 301641, 258823, 234177]
monstersync_tput = [233451, 189537, 158530, 131540]
lock_tput = [222723, 214223, 199820, 182842]

ax.set_title("Low contention")
ax.plot(mnodes, abe_tput, label="abe")
ax.plot(mnodes, monsterasync_tput, label="monster async")
ax.plot(mnodes, monstersync_tput, label="monster sync")
ax.plot(mnodes, lock_tput, '--2', color="magenta", label="lock (Tigon)")
ax.set_xticks(mnodes)
ax.set_xlabel("# of memory nodes")
ax.set_ylabel("Throughput (ops/s)")
ax.set_yticks([100_000, 300_000, 500_000], labels=["100k", "300k", "500k"])

ax = axs[1]
abe_tput= [82000, 54285, 45098, 30139]
monsterasync_tput = [112000, 98375, 87000, 80000 ]
monstersync_tput = [ 113875, 87875, 54625, 43625 ]
lock_tput = [39251, 35871, 35871, 35661]

ax.set_title("High contention")
ax.plot(mnodes, abe_tput, label="LOBSTER")
ax.plot(mnodes, monsterasync_tput, label="MONSTER async")
ax.plot(mnodes, monstersync_tput, label="MONSTER round-based")
ax.plot(mnodes, lock_tput, '--2', color="magenta", label="Lock (Tigon)")

ax.set_xlabel("# of memory nodes")
ax.set_xticks(mnodes)
# ax.set_yscale("log")
ax.legend(loc="upper center", bbox_to_anchor=(-0.2, 1.75),ncols=2)

# %%
fig.savefig("mnodes_scale.pdf",bbox_inches = "tight", dpi=150)

# %%
fig.savefig("object_scale.pdf",bbox_inches = "tight", dpi=150)
